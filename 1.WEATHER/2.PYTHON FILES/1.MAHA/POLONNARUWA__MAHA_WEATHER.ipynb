# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load your weather data into a DataFrame
# Replace 'AMPARA_MAHA_SEASON.csv' with the path to your actual data file
data = pd.read_csv('POLONNARUWA_MAHA_SEASON.csv')

# %%
# Display the first few rows of the DataFrame to understand its structure
print(data.head())
# Out:
#    Year  Maha Total Rainfall  Maha Temp Average  Maha Average Of Max Temp  \
# 0  1993           1226.99500          25.368178                 28.489027
# 1  1994            398.68375          26.477128                 30.818194
# 2  1995            193.85875          27.190679                 32.161074
# 3  1996            166.10750          27.137881                 32.652791
# 4  1997            632.61875          26.686497                 30.760193
#
#    Maha Highest Monthly  Average of MaxTemp  Maha Average Of Min Temp  \
# 0                                 30.232419                 23.074010
# 1                                 34.421774                 23.440664
# 2                                 35.468226                 23.704986
# 3                                 35.650524                 23.156455
# 4                                 35.185766                 23.738241
#
#    Maha Lowest Monthly  Average of Min Temp
# 0                                 22.200685
# 1                                 22.846429
# 2                                 22.694395
# 3                                 22.121613
# 4                                 22.822419

# %%
# Generate descriptive statistics for the weather data
stats_summary = data.describe()
print("\nStatistical Summary:")
print(stats_summary)
# Out:
# Statistical Summary:
#               Year  Maha Total Rainfall  Maha Temp Average  \
# count    32.000000            31.000000          31.000000
# mean   2008.500000          1123.706815          25.893367
# std       9.380832           548.854972           0.488554
# min    1993.000000           166.107500          25.147915
# 25%    2000.750000           762.947500          25.553362
# 50%    2008.500000          1045.301250          25.813537
# 75%    2016.250000          1387.058125          26.031144
# max    2024.000000          2499.617500          27.190679
#
#        Maha Average Of Max Temp  Maha Highest Monthly  Average of MaxTemp  \
# count                 31.000000                                 31.000000
# mean                  29.599366                                 32.354355
# std                    1.024517                                  1.652841
# min                   28.061303                                 30.099274
# 25%                   28.895964                                 31.031613
# 50%                   29.367156                                 32.070444
# 75%                   29.999696                                 33.501391
# max                   32.652791                                 35.650524
#
#        Maha Average Of Min Temp  Maha Lowest Monthly  Average of Min Temp
# count                 31.000000                                 31.000000
# mean                  23.179716                                 22.175807
# std                    0.285657                                  0.467784
# min                   22.744554                                 20.868616
# 25%                   22.990182                                 21.894778
# 50%                   23.124796                                 22.200685
# 75%                   23.306920                                 22.486193
# max                   23.926945                                 23.190726

# %%
# Set up the matplotlib figure for histograms and boxplots
plt.figure(figsize=(15, 10))

# List of columns to plot
columns = ['Maha Total Rainfall', 'Maha Temp Average', 'Maha Average Of Max Temp', 'Maha Highest Monthly  Average of MaxTemp','Maha Average Of Min Temp','Maha Lowest Monthly  Average of Min Temp']
labels = ['Total Rainfall (mm)', 'Average Temperature (°C)', 'Average Max Temperature (°C)','Higest of Average monthly Max Temperature (°C)' ,'Average Min Temperature (°C)','Lowest of Average monthly Min Temperature (°C)']

# Create subplots for histograms and boxplots
fig, axs = plt.subplots(nrows=6, ncols=2, figsize=(15, 20))

# Loop through each column to create histograms and boxplots
for i, (col, label) in enumerate(zip(columns, labels)):
    # Histogram with KDE
    sns.histplot(data[col], kde=True, bins=30, ax=axs[i, 0])
    axs[i, 0].set_title(f'Distribution of {label}')
    axs[i, 0].set_xlabel(label)
    axs[i, 0].set_ylabel('Frequency')

    # Boxplot
    sns.boxplot(y=data[col], ax=axs[i, 1])
    axs[i, 1].set_title(f'Boxplot of {label}')

# Adjust layout to prevent overlap
plt.tight_layout()
plt.show()

# %%
# Create subplots
fig, axs = plt.subplots(nrows=6, ncols=1, figsize=(15, 30))

# Loop through each column and plot in separate subplots
for ax, col, label in zip(axs, columns, labels):
    ax.plot(data['Year'], data[col], marker='o', label=label)
    ax.set_title(label)
    ax.set_xlabel('YEAR')
    ax.set_ylabel(label)
    ax.grid()
    ax.legend()

# Adjust layout to prevent overlap
plt.tight_layout()

# Display the plots
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
