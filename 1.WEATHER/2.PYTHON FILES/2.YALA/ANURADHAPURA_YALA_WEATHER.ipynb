# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load your weather data into a DataFrame
# Replace 'AMPARA_Yala_SEASON.csv' with the path to your actual data file
data = pd.read_csv('ANURADHAPURA_YALA_SEASON.csv')

# %%
# Display the first few rows of the DataFrame to understand its structure
print(data.head())
# Out:
#    Year  Yala Total Rainfall  Yala Temp Average  Yala Average Of Max Temp  \
# 0  1993              328.947          27.926691                 32.650215
# 1  1994              315.933          27.572731                 31.909571
# 2  1995               98.603          28.591752                 33.244709
# 3  1996              160.265          28.364813                 33.034637
# 4  1997              284.688          28.462200                 33.089985
#
#    Yala Highest Monthly  Average of Max Temp  Yala Average Of Min Temp  \
# 0                                  36.053533                 24.738272
# 1                                  32.775968                 24.589922
# 2                                  34.659133                 25.382961
# 3                                  36.273387                 25.217881
# 4                                  35.612867                 25.279092
#
#    Yala Lowest Monthly  Average of Min Temp
# 0                                 24.366484
# ...

# %%
# Generate descriptive statistics for the weather data
stats_summary = data.describe()
print("\nStatistical Summary:")
print(stats_summary)
# Out:
# Statistical Summary:
#               Year  Yala Total Rainfall  Yala Temp Average  \
# count    32.000000            31.000000          31.000000
# mean   2008.500000           393.256194          28.018986
# std       9.380832           137.192376           0.446776
# min    1993.000000            98.603000          27.307427
# 25%    2000.750000           308.775000          27.624682
# 50%    2008.500000           364.449000          28.067906
# 75%    2016.250000           503.279500          28.339365
# max    2024.000000           651.316000          29.149970
#
#        Yala Average Of Max Temp  Yala Highest Monthly  Average of Max Temp  \
# count                 31.000000                                  31.000000
# mean                  32.401509                                  34.312879
# std                    0.711420                                   1.478612
# min                   31.115206                                  31.928767
# ...

# %%
# Set up the matplotlib figure for histograms and boxplots
plt.figure(figsize=(15, 10))

# List of columns to plot
columns = ['Yala Total Rainfall', 'Yala Temp Average', 'Yala Average Of Max Temp', 'Yala Highest Monthly  Average of Max Temp','Yala Average Of Min Temp','Yala Lowest Monthly  Average of Min Temp']
labels = ['Total Rainfall (mm)', 'Average Temperature (°C)', 'Average Max Temperature (°C)','Higest of Average monthly Max Temperature (°C)' ,'Average Min Temperature (°C)','Lowest of Average monthly Min Temperature (°C)']

# Create subplots for histograms and boxplots
fig, axs = plt.subplots(nrows=6, ncols=2, figsize=(15, 20))

# Loop through each column to create histograms and boxplots
for i, (col, label) in enumerate(zip(columns, labels)):
    # Histogram with KDE
    sns.histplot(data[col], kde=True, bins=30, ax=axs[i, 0])
    axs[i, 0].set_title(f'Distribution of {label}')
    axs[i, 0].set_xlabel(label)
    axs[i, 0].set_ylabel('Frequency')

    # Boxplot
    sns.boxplot(y=data[col], ax=axs[i, 1])
    axs[i, 1].set_title(f'Boxplot of {label}')

# Adjust layout to prevent overlap
plt.tight_layout()
plt.show()

# %%
# Create subplots
fig, axs = plt.subplots(nrows=6, ncols=1, figsize=(15, 30))

# Loop through each column and plot in separate subplots
for ax, col, label in zip(axs, columns, labels):
    ax.plot(data['Year'], data[col], marker='o', label=label)
    ax.set_title(label)
    ax.set_xlabel('YEAR')
    ax.set_ylabel(label)
    ax.grid()
    ax.legend()

# Adjust layout to prevent overlap
plt.tight_layout()

# Display the plots
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
