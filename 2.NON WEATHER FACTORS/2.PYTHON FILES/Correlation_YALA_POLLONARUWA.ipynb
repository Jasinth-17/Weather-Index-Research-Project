# %%
# Import necessary libraries
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

# %%
# Load your dataset (make sure to adjust the file name/path)
df = pd.read_csv('YALA_POLLONNARUWA.csv')  # Replace with your actual file name

# %%
# Display the first few rows of the dataframe
print(df.head())
# Out:
#    YEAR  MAINLY BY TRACTOR   BUFFALOE PLOUGHED   BUFFALOE MUDDED   \
# 0  2015              99.80%               0.20%             0.00%
# 1  2016              95.70%               4.30%             0.00%
# 2  2017              98.70%               1.30%             0.00%
# 3  2018              98.00%               2.00%             0.00%
# 4  2019              98.10%               1.90%             0.00%
#
#    BY MAMOTEE   MANNUAL   MACHINE    SCORE MAINLY BY TRACTOR   \
# 0        0.00%    31.30%    68.70%                     15.968
# 1        0.00%    13.00%    87.00%                     15.312
# 2        0.00%     8.30%    91.70%                     15.792
# 3        0.00%     5.70%    94.30%                     15.680
# 4        0.00%    11.50%    88.50%                     15.696
#
#     SCORE BUFFALOE PLOUGHED    SCORE BUFFALOE MUDDED   ...  \
# 0                      0.028                        0  ...
# 1                      0.602                        0  ...
# 2                      0.182                        0  ...
# 3                      0.280                        0  ...
# 4                      0.266                        0  ...
#
#     SCORE LONG GRAIN RED    SCORE SHORT GRAIN WHITE   \
# 0                    -                          0.89
# 1                    0.02                       1.52
# 2                    0.02                       1.15
# 3                    -                          2.80
# 4                    0.02                       1.90
#
#     SCORE  LONG GRAIN WHITE   SCORE OTHERS  TOTALTECHNOLOGYSCORE  \
# 0                       3.89           -                   31.68
# 1                       2.70           -                   31.78
# 2                       3.40           -                   31.89
# 3                       1.51           -                   31.90
# 4                       2.29           0.12                31.85
#
#   TOTALFERTILIZERSCORE TOTALWEEDINGSCORE  TOTALINSECTICIDESSCORE  \
# 0                 4.48              3.96                    1.01
# 1                 4.49              3.91                    0.93
# 2                 4.39              3.98                    1.24
# 3                 4.52              3.95                    1.62
# 4                 4.33              3.93                    0.74
#
#   TOTALSEEDSCORE  AverageYieldKgPERha
# 0           4.78                 5131
# 1           4.47                 5047
# 2           4.65                 4878
# 3           4.30                 5070
# 4           4.34                 5511
#
# [5 rows x 49 columns]

# %%
# Define the variables
variables = ['TOTALTECHNOLOGYSCORE', 'TOTALFERTILIZERSCORE', 'TOTALWEEDINGSCORE', 'TOTALINSECTICIDESSCORE', 'TOTALSEEDSCORE']

# %%
plt.figure(figsize=(15, 10))

for i, var in enumerate(variables):
    # Prepare the data
    X = df[[var]]  # Independent variable
    Y = df['AverageYieldKgPERha']  # Dependent variable

    # Polynomial fitting (degree 2)
    coefficients = np.polyfit(X[var].values, Y, 2)  # Change degree as needed
    polynomial = np.poly1d(coefficients)

    # Predict values
    Y_poly_pred = polynomial(X[var].values)

    # Plotting
    plt.subplot(2, 3, i + 1)
    plt.scatter(X, Y, color='blue', label='Data Points')
    plt.plot(X, Y_poly_pred, color='green', label='Polynomial Regression Line')  # Polynomial regression line
    plt.title(f'YALA_POL: {var} vs Average Yield')
    plt.xlabel(var)
    plt.ylabel('Average Yield (Kg/ha)')
    plt.legend()
    plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Define the variables to plot
#variables = ['TOTALTECHNOLOGYSCORE', 'TOTALFERTILIZERSCORE', 'TOTALWEEDINGSCORE', 'TOTALINSECTICIDESSCORE', 'TOTALSEEDSCORE']

plt.figure(figsize=(15, 10))

for i, var in enumerate(variables):
    # Prepare the data
    X = df[[var]]  # Independent variable
    Y = df['AverageYieldKgPERha']  # Dependent variable

    # Create and fit the linear regression model
    model = LinearRegression()
    model.fit(X, Y)

    # Predict values
    Y_pred = model.predict(X)

    # Plotting
    plt.subplot(2, 3, i + 1)
    plt.scatter(X, Y, color='blue', label='Data Points')
    plt.plot(X, Y_pred, color='red', label='Regression Line')  # Regression line
    plt.title(f'YALA_POL {var} vs Average Yield')
    plt.xlabel(var)
    plt.ylabel('Average Yield (Kg/ha)')
    plt.legend()
    plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Define the variables to calculate correlation with Average Yield
#variables = ['TOTALSEEDSCORE', 'TOTALWEEDINGSCORE', 'TOTALFERTILIZERSCORE', 'TOTALTECHNOLOGYSCORE', 'TOTALINSECTICIDESSCORE']

# Calculate and print correlations
for var in variables:
    correlation = df[var].corr(df['AverageYieldKgPERha'])
    print(f'YALA_POL_Correlation between {var} and Average Yield: {correlation}')
# Out:
# YALA_POL_Correlation between TOTALTECHNOLOGYSCORE and Average Yield: -0.30475274866091806
# YALA_POL_Correlation between TOTALFERTILIZERSCORE and Average Yield: -0.9025095568869802
# YALA_POL_Correlation between TOTALWEEDINGSCORE and Average Yield: 0.5076486856447142
# YALA_POL_Correlation between TOTALINSECTICIDESSCORE and Average Yield: 0.14273025698308664
# YALA_POL_Correlation between TOTALSEEDSCORE and Average Yield: -0.3012251964669055

# %%
# Plotting scatter plots for each variable against Average Yield
#variables = ['TOTALTECHNOLOGYSCORE', 'TOTALFERTILIZERSCORE', 'TOTALWEEDINGSCORE', 'TOTALINSECTICIDESSCORE', 'TOTALSEEDSCORE']

plt.figure(figsize=(15, 10))

for i, var in enumerate(variables):
    plt.subplot(2, 3, i + 1)
    sns.scatterplot(x=df[var], y=df['AverageYieldKgPERha'])
    plt.title(f'YALA_POL {var} vs Average Yield')
    plt.xlabel(var)
    plt.ylabel('Average Yield (Kg/ha)')
    plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Define the variables to plot
#variables = ['TOTALTECHNOLOGYSCORE', 'TOTALFERTILIZERSCORE', 'TOTALWEEDINGSCORE', 'TOTALINSECTICIDESSCORE', 'TOTALSEEDSCORE']

plt.figure(figsize=(15, 10))

for i, var in enumerate(variables):
    plt.subplot(2, 3, i + 1)
    sns.regplot(x=df[var], y=df['AverageYieldKgPERha'], scatter_kws={'color': 'blue'}, line_kws={'color': 'red'})
    plt.title(f'YALA_POL {var} vs Average Yield')
    plt.xlabel(var)
    plt.ylabel('Average Yield (Kg/ha)')
    plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Define the variables to plot
#variables = ['TOTALTECHNOLOGYSCORE', 'TOTALFERTILIZERSCORE', 'TOTALWEEDINGSCORE', 'TOTALINSECTICIDESSCORE', 'TOTALSEEDSCORE']

plt.figure(figsize=(15, 10))

for i, var in enumerate(variables):
    plt.subplot(2, 3, i + 1)

    # Fit the regression model
    X = df[var]
    y = df['AverageYieldKgPERha']

    # Add a constant to the model (intercept)
    X_with_const = sm.add_constant(X)
    model = sm.OLS(y, X_with_const).fit()

    # Get predictions
    predictions = model.predict(X_with_const)

    # Calculate RMSE
    rmse = np.sqrt(np.mean((predictions - y) ** 2))

    # Plotting
    sns.regplot(x=X, y=y, scatter_kws={'color': 'blue'}, line_kws={'color': 'red'})

    # Title and labels
    plt.title(f'YALA_POL {var} vs Average Yield\nR²={model.rsquared:.2f}, RMSE={rmse:.2f}')
    plt.xlabel(var)
    plt.ylabel('Average Yield (Kg/ha)')
    plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Define the variables to calculate correlation with Average Yield
#variables = ['TOTALTECHNOLOGYSCORE', 'TOTALFERTILIZERSCORE', 'TOTALWEEDINGSCORE', 'TOTALINSECTICIDESSCORE', 'TOTALSEEDSCORE']

# Calculate and print both Pearson and Spearman correlations
for var in variables:
    pearson_corr = df[var].corr(df['AverageYieldKgPERha'])
    spearman_corr = df[var].corr(df['AverageYieldKgPERha'], method='spearman')
    print(f'YALA_POL_Correlation between {var} and Average Yield:')
    print(f'  Pearson Correlation: {pearson_corr}')
    print(f'  Spearman Correlation: {spearman_corr}\n')
# Out:
# YALA_POL_Correlation between TOTALTECHNOLOGYSCORE and Average Yield:
#   Pearson Correlation: -0.30475274866091806
#   Spearman Correlation: -0.25318484177091666
#
# YALA_POL_Correlation between TOTALFERTILIZERSCORE and Average Yield:
#   Pearson Correlation: -0.9025095568869802
#   Spearman Correlation: -0.7333333333333334
#
# YALA_POL_Correlation between TOTALWEEDINGSCORE and Average Yield:
#   Pearson Correlation: 0.5076486856447142
#   Spearman Correlation: 0.2468643939200371
#
# YALA_POL_Correlation between TOTALINSECTICIDESSCORE and Average Yield:
#   Pearson Correlation: 0.14273025698308664
#   Spearman Correlation: -0.06666666666666667
#
# YALA_POL_Correlation between TOTALSEEDSCORE and Average Yield:
#   Pearson Correlation: -0.3012251964669055
#   Spearman Correlation: -0.18333333333333335
