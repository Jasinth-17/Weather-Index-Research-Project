# %%
# Import necessary libraries
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

# %%
# Load your dataset (make sure to adjust the file name/path)
df = pd.read_csv('MAHA_ANURADHAPURA.csv')  # Replace with your actual file name

# %%
# Display the first few rows of the dataframe
print(df.head())
# Out:
#    YEAR  MAINLY BY TRACTOR   BUFFALOE PLOUGHED   BUFFALOE MUDDED   \
# 0  2014              98.70%               1.30%             0.00%
# 1  2015              99.20%               0.80%             0.00%
# 2  2016              99.90%               0.10%             0.00%
# 3  2017              98.70%               0.70%             0.00%
# 4  2018             100.00%               0.00%             0.00%
#
#    BY MAMOTEE   MANNUAL   MACHINE    SCORE MAINLY BY TRACTOR   \
# 0        0.00%    38.50%    61.50%                     15.792
# 1        0.00%    37.40%    62.60%                     15.872
# 2        0.00%    25.80%    74.20%                     15.984
# 3        0.60%     4.50%    95.50%                     15.792
# 4        0.00%    13.30%    86.70%                     16.000
#
#     SCORE BUFFALOE PLOUGHED    SCORE BUFFALOE MUDDED   ...  \
# 0                      0.182                      0.0  ...
# 1                      0.112                      0.0  ...
# 2                      0.014                      0.0  ...
# 3                      0.098                      0.0  ...
# 4                      0.000                      0.0  ...
#
#     SCORE LONG GRAIN RED    SCORE SHORT GRAIN WHITE   \
# 0                    0.01                       0.96
# 1                    0.02                       1.62
# 2                    -                          0.96
# 3                    0.01                       0.65
# 4                    -                          1.36
#
#     SCORE  LONG GRAIN WHITE   SCORE OTHERS  TOTALTECHNOLOGYSCORE  \
# 0                       3.61           0.01               31.589
# 1                       2.84           0.01               31.610
# 2                       3.80           -                  31.740
# 3                       4.18           -                  31.929
# 4                       3.29           -                  31.867
#
#   TOTALFERTILIZERSCORE TOTALWEEDINGSCORE  TOTALINSECTICIDESSCORE  \
# 0                 4.06              3.87                    1.16
# 1                 4.07              3.88                    1.22
# 2                 4.06              3.89                    0.70
# 3                 4.12              3.85                    1.20
# 4                 4.24              3.91                    1.41
#
#   TOTALSEEDSCORE  AverageYieldKgPERha
# 0           4.68                 3898
# 1           4.54                 4802
# 2           4.76                 4748
# 3           4.84                 4608
# 4           4.66                 4414
#
# [5 rows x 49 columns]

# %%
# Define the variables
variables = ['TOTALTECHNOLOGYSCORE', 'TOTALFERTILIZERSCORE', 'TOTALWEEDINGSCORE', 'TOTALINSECTICIDESSCORE', 'TOTALSEEDSCORE']

# %%
plt.figure(figsize=(15, 10))

for i, var in enumerate(variables):
    # Prepare the data
    X = df[[var]]  # Independent variable
    Y = df['AverageYieldKgPERha']  # Dependent variable

    # Polynomial fitting (degree 2)
    coefficients = np.polyfit(X[var].values, Y, 2)  # Change degree as needed
    polynomial = np.poly1d(coefficients)

    # Predict values
    Y_poly_pred = polynomial(X[var].values)

    # Plotting
    plt.subplot(2, 3, i + 1)
    plt.scatter(X, Y, color='blue', label='Data Points')
    plt.plot(X, Y_poly_pred, color='green', label='Polynomial Regression Line')  # Polynomial regression line
    plt.title(f'MAHA_ANU: {var} vs Average Yield')
    plt.xlabel(var)
    plt.ylabel('Average Yield (Kg/ha)')
    plt.legend()
    plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Define the variables to plot
#variables = ['TOTALTECHNOLOGYSCORE', 'TOTALFERTILIZERSCORE', 'TOTALWEEDINGSCORE', 'TOTALINSECTICIDESSCORE', 'TOTALSEEDSCORE']

plt.figure(figsize=(15, 10))

for i, var in enumerate(variables):
    # Prepare the data
    X = df[[var]]  # Independent variable
    Y = df['AverageYieldKgPERha']  # Dependent variable

    # Create and fit the linear regression model
    model = LinearRegression()
    model.fit(X, Y)

    # Predict values
    Y_pred = model.predict(X)

    # Plotting
    plt.subplot(2, 3, i + 1)
    plt.scatter(X, Y, color='blue', label='Data Points')
    plt.plot(X, Y_pred, color='red', label='Regression Line')  # Regression line
    plt.title(f'MAHA_ANU {var} vs Average Yield')
    plt.xlabel(var)
    plt.ylabel('Average Yield (Kg/ha)')
    plt.legend()
    plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Define the variables to calculate correlation with Average Yield
#variables = ['TOTALSEEDSCORE', 'TOTALWEEDINGSCORE', 'TOTALFERTILIZERSCORE', 'TOTALTECHNOLOGYSCORE', 'TOTALINSECTICIDESSCORE']

# Calculate and print correlations
for var in variables:
    correlation = df[var].corr(df['AverageYieldKgPERha'])
    print(f'MAHA_ANU_Correlation between {var} and Average Yield: {correlation}')
# Out:
# MAHA_ANU_Correlation between TOTALTECHNOLOGYSCORE and Average Yield: 0.26002004295427406
# MAHA_ANU_Correlation between TOTALFERTILIZERSCORE and Average Yield: -0.38665363406171294
# MAHA_ANU_Correlation between TOTALWEEDINGSCORE and Average Yield: 0.21997454421263068
# MAHA_ANU_Correlation between TOTALINSECTICIDESSCORE and Average Yield: -0.07207745411046858
# MAHA_ANU_Correlation between TOTALSEEDSCORE and Average Yield: 0.7738020039430806

# %%
# Plotting scatter plots for each variable against Average Yield
#variables = ['TOTALTECHNOLOGYSCORE', 'TOTALFERTILIZERSCORE', 'TOTALWEEDINGSCORE', 'TOTALINSECTICIDESSCORE', 'TOTALSEEDSCORE']

plt.figure(figsize=(15, 10))

for i, var in enumerate(variables):
    plt.subplot(2, 3, i + 1)
    sns.scatterplot(x=df[var], y=df['AverageYieldKgPERha'])
    plt.title(f'MAHA_ANU {var} vs Average Yield')
    plt.xlabel(var)
    plt.ylabel('Average Yield (Kg/ha)')
    plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Define the variables to plot
#variables = ['TOTALTECHNOLOGYSCORE', 'TOTALFERTILIZERSCORE', 'TOTALWEEDINGSCORE', 'TOTALINSECTICIDESSCORE', 'TOTALSEEDSCORE']

plt.figure(figsize=(15, 10))

for i, var in enumerate(variables):
    plt.subplot(2, 3, i + 1)
    sns.regplot(x=df[var], y=df['AverageYieldKgPERha'], scatter_kws={'color': 'blue'}, line_kws={'color': 'red'})
    plt.title(f'MAHA_ANU {var} vs Average Yield')
    plt.xlabel(var)
    plt.ylabel('Average Yield (Kg/ha)')
    plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Define the variables to plot
#variables = ['TOTALTECHNOLOGYSCORE', 'TOTALFERTILIZERSCORE', 'TOTALWEEDINGSCORE', 'TOTALINSECTICIDESSCORE', 'TOTALSEEDSCORE']

plt.figure(figsize=(15, 10))

for i, var in enumerate(variables):
    plt.subplot(2, 3, i + 1)

    # Fit the regression model
    X = df[var]
    y = df['AverageYieldKgPERha']

    # Add a constant to the model (intercept)
    X_with_const = sm.add_constant(X)
    model = sm.OLS(y, X_with_const).fit()

    # Get predictions
    predictions = model.predict(X_with_const)

    # Calculate RMSE
    rmse = np.sqrt(np.mean((predictions - y) ** 2))

    # Plotting
    sns.regplot(x=X, y=y, scatter_kws={'color': 'blue'}, line_kws={'color': 'red'})

    # Title and labels
    plt.title(f'MAHA_ANU {var} vs Average Yield\nR²={model.rsquared:.2f}, RMSE={rmse:.2f}')
    plt.xlabel(var)
    plt.ylabel('Average Yield (Kg/ha)')
    plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Define the variables to calculate correlation with Average Yield
#variables = ['TOTALTECHNOLOGYSCORE', 'TOTALFERTILIZERSCORE', 'TOTALWEEDINGSCORE', 'TOTALINSECTICIDESSCORE', 'TOTALSEEDSCORE']

# Calculate and print both Pearson and Spearman correlations
for var in variables:
    pearson_corr = df[var].corr(df['AverageYieldKgPERha'])
    spearman_corr = df[var].corr(df['AverageYieldKgPERha'], method='spearman')
    print(f'MAHA_ANU_Correlation between {var} and Average Yield:')
    print(f'  Pearson Correlation: {pearson_corr}')
    print(f'  Spearman Correlation: {spearman_corr}\n')
# Out:
# MAHA_ANU_Correlation between TOTALTECHNOLOGYSCORE and Average Yield:
#   Pearson Correlation: 0.26002004295427406
#   Spearman Correlation: 0.5
#
# MAHA_ANU_Correlation between TOTALFERTILIZERSCORE and Average Yield:
#   Pearson Correlation: -0.38665363406171294
#   Spearman Correlation: -0.20920685218893076
#
# MAHA_ANU_Correlation between TOTALWEEDINGSCORE and Average Yield:
#   Pearson Correlation: 0.21997454421263068
#   Spearman Correlation: 0.41666666666666663
#
# MAHA_ANU_Correlation between TOTALINSECTICIDESSCORE and Average Yield:
#   Pearson Correlation: -0.07207745411046858
#   Spearman Correlation: 0.19999999999999998
#
# MAHA_ANU_Correlation between TOTALSEEDSCORE and Average Yield:
#   Pearson Correlation: 0.7738020039430806
#   Spearman Correlation: 0.5857791861290061

# %%
import pandas as pd
from scipy.stats import pearsonr
# Calculate Pearson's correlation
for var in variables:
    correlation_coefficient, p_value = pearsonr(df['AverageYieldKgPERha'], df[var])
    print(f"Variable: {var}")
    print(f"  Pearson Correlation Coefficient (r): {correlation_coefficient:.4f}")
    print(f"  P-value: {p_value:.4f}")
    alpha = 0.05
    if p_value < alpha:
        print(f"  The correlation is statistically significant (p < {alpha}).")
        if correlation_coefficient > 0:
            print("  Positive linear relationship.")
        else:
            print("  Negative linear relationship.")
    else:
        print(f"  The correlation is not statistically significant (p >= {alpha}).")
    print()
# Out:
# Variable: TOTALTECHNOLOGYSCORE
#   Pearson Correlation Coefficient (r): 0.2600
#   P-value: 0.4992
#   The correlation is not statistically significant (p >= 0.05).
#
# Variable: TOTALFERTILIZERSCORE
#   Pearson Correlation Coefficient (r): -0.3867
#   P-value: 0.3040
#   The correlation is not statistically significant (p >= 0.05).
#
# Variable: TOTALWEEDINGSCORE
#   Pearson Correlation Coefficient (r): 0.2200
#   P-value: 0.5696
#   The correlation is not statistically significant (p >= 0.05).
#
# Variable: TOTALINSECTICIDESSCORE
#   Pearson Correlation Coefficient (r): -0.0721
#   P-value: 0.8538
#   The correlation is not statistically significant (p >= 0.05).
#
# Variable: TOTALSEEDSCORE
#   Pearson Correlation Coefficient (r): 0.7738
#   P-value: 0.0144
#   The correlation is statistically significant (p < 0.05).
#   Positive linear relationship.
