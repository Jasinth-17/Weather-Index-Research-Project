# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Load your dataset
data = pd.read_csv('CORRELATIONS_YALA_ANURADHAPURA.csv')  # Uncomment and modify to load your dataset

# %%
# Check the first few rows of the dataset
print(data.head())
# Out:
#      Year  Yala Total Rainfall  Yala Temp Average  Yala Average Of Max Temp  \
# 0  1993.0              328.947          27.926691                 32.650215
# 1  1994.0              315.933          27.572731                 31.909571
# 2  1995.0               98.603          28.591752                 33.244709
# 3  1996.0              160.265          28.364813                 33.034637
# 4  1997.0              284.688          28.462200                 33.089985
#
#    Yala Highest Monthly  Average of Max Temp  Yala Average Of Min Temp  \
# 0                                  36.053533                 24.738272
# 1                                  32.775968                 24.589922
# 2                                  34.659133                 25.382961
# 3                                  36.273387                 25.217881
# 4                                  35.612867                 25.279092
#
#    Yala Lowest Monthly  Average of Min Temp  Actual Yield (kg/ha)  \
# 0                                 24.366484            3123.00000
# 1                                 23.882533            3203.30005
# 2                                 25.106290            3257.89990
# 3                                 24.573677            3827.60010
# 4                                 24.733833            3454.00000
#
#    Trend (kg/ha)  Detrended Additive (kg/ha)  Detrended Multiplicative (kg/ha)
# 0    3140.306004                  -17.306003                          0.994489
# 1    3194.388023                    8.912027                          1.002790
# 2    3296.077963                  -38.178063                          0.988417
# 3    3641.816041                  185.784059                          1.051014
# 4    3584.925020                 -130.925020                          0.963479

# %%
# Distribution plots for Actual Yield and Detrended Yield
plt.figure(figsize=(12, 6))

# Actual Yield Distribution
plt.subplot(1, 3, 1)
sns.histplot(data['Actual Yield (kg/ha)'], kde=True)
plt.title('Distribution of Actual Yield')
plt.xlabel('Actual Yield (kg/ha)')
plt.ylabel('Frequency')

# Detrended Additive Yield Distribution
plt.subplot(1, 3, 2)
sns.histplot(data['Detrended Additive (kg/ha)'], kde=True)
plt.title('Distribution of Detrended Additive Yield')
plt.xlabel('Detrended Additive Yield (kg/ha)')
plt.ylabel('Frequency')


# Detrended Additive Yield Distribution
plt.subplot(1, 3, 3)
sns.histplot(data['Detrended Multiplicative (kg/ha)'], kde=True)
plt.title('Distribution of Detrended multiplicative Yield')
plt.xlabel('Detrended multiplicative Yield (kg/ha)')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
# Correlation analysis
weather_columns = ['Yala Total Rainfall', 'Yala Temp Average', 'Yala Average Of Max Temp', 'Yala Highest Monthly  Average of Max Temp','Yala Average Of Min Temp','Yala Lowest Monthly  Average of Min Temp']
yield_columns = ['Actual Yield (kg/ha)',
                 'Trend (kg/ha)',
                 'Detrended Additive (kg/ha)',
                 'Detrended Multiplicative (kg/ha)']

for yield_col in yield_columns:
    for weather_col in weather_columns:
        # Scatter plot with regression line
        plt.figure(figsize=(8, 6))
        sns.regplot(x=data[weather_col], y=data[yield_col], ci=None)
        plt.title(f'Scatter Plot of {yield_col} vs {weather_col}')
        plt.xlabel(weather_col)
        plt.ylabel(yield_col)

        plt.show()

# Optional: Display correlation matrix
correlation_matrix = data[weather_columns + yield_columns].corr()
print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#                                            Yala Total Rainfall  \
# Yala Total Rainfall                                   1.000000
# Yala Temp Average                                    -0.412585
# Yala Average Of Max Temp                             -0.497196
# Yala Highest Monthly  Average of Max Temp            -0.189702
# Yala Average Of Min Temp                             -0.245000
# Yala Lowest Monthly  Average of Min Temp             -0.211774
# Actual Yield (kg/ha)                                  0.443680
# Trend (kg/ha)                                         0.490378
# Detrended Additive (kg/ha)                            0.016952
# Detrended Multiplicative (kg/ha)                     -0.022363
#
#                                            Yala Temp Average  \
# Yala Total Rainfall                                -0.412585
# Yala Temp Average                                   1.000000
# Yala Average Of Max Temp                            0.973394
# Yala Highest Monthly  Average of Max Temp           0.758793
# Yala Average Of Min Temp                            0.930667
# Yala Lowest Monthly  Average of Min Temp            0.707894
# Actual Yield (kg/ha)                               -0.052676
# Trend (kg/ha)                                      -0.068571
# Detrended Additive (kg/ha)                          0.031014
# Detrended Multiplicative (kg/ha)                    0.054197
#
#                                            Yala Average Of Max Temp  \
# Yala Total Rainfall                                       -0.497196
# Yala Temp Average                                          0.973394
# Yala Average Of Max Temp                                   1.000000
# Yala Highest Monthly  Average of Max Temp                  0.771063
# Yala Average Of Min Temp                                   0.827808
# Yala Lowest Monthly  Average of Min Temp                   0.668866
# Actual Yield (kg/ha)                                      -0.118248
# Trend (kg/ha)                                             -0.149540
# Detrended Additive (kg/ha)                                 0.055620
# Detrended Multiplicative (kg/ha)                           0.078841
#
#                                            Yala Highest Monthly  Average of Max Temp  \
# Yala Total Rainfall                                                        -0.189702
# Yala Temp Average                                                           0.758793
# Yala Average Of Max Temp                                                    0.771063
# Yala Highest Monthly  Average of Max Temp                                   1.000000
# Yala Average Of Min Temp                                                    0.636422
# Yala Lowest Monthly  Average of Min Temp                                    0.492483
# Actual Yield (kg/ha)                                                       -0.073433
# Trend (kg/ha)                                                              -0.150722
# Detrended Additive (kg/ha)                                                  0.219162
# Detrended Multiplicative (kg/ha)                                            0.240338
#
#                                            Yala Average Of Min Temp  \
# Yala Total Rainfall                                       -0.245000
# Yala Temp Average                                          0.930667
# Yala Average Of Max Temp                                   0.827808
# Yala Highest Monthly  Average of Max Temp                  0.636422
# Yala Average Of Min Temp                                   1.000000
# Yala Lowest Monthly  Average of Min Temp                   0.724948
# Actual Yield (kg/ha)                                       0.069348
# Trend (kg/ha)                                              0.085598
# Detrended Additive (kg/ha)                                -0.025914
# Detrended Multiplicative (kg/ha)                          -0.001466
#
#                                            Yala Lowest Monthly  Average of Min Temp  \
# Yala Total Rainfall                                                       -0.211774
# Yala Temp Average                                                          0.707894
# Yala Average Of Max Temp                                                   0.668866
# Yala Highest Monthly  Average of Max Temp                                  0.492483
# Yala Average Of Min Temp                                                   0.724948
# Yala Lowest Monthly  Average of Min Temp                                   1.000000
# Actual Yield (kg/ha)                                                      -0.135555
# Trend (kg/ha)                                                             -0.147821
# Detrended Additive (kg/ha)                                                -0.011565
# Detrended Multiplicative (kg/ha)                                          -0.015634
#
#                                            Actual Yield (kg/ha)  \
# Yala Total Rainfall                                    0.443680
# Yala Temp Average                                     -0.052676
# Yala Average Of Max Temp                              -0.118248
# Yala Highest Monthly  Average of Max Temp             -0.073433
# Yala Average Of Min Temp                               0.069348
# Yala Lowest Monthly  Average of Min Temp              -0.135555
# Actual Yield (kg/ha)                                   1.000000
# Trend (kg/ha)                                          0.962198
# Detrended Additive (kg/ha)                             0.494692
# Detrended Multiplicative (kg/ha)                       0.481285
#
#                                            Trend (kg/ha)  \
# Yala Total Rainfall                             0.490378
# Yala Temp Average                              -0.068571
# Yala Average Of Max Temp                       -0.149540
# Yala Highest Monthly  Average of Max Temp      -0.150722
# Yala Average Of Min Temp                        0.085598
# Yala Lowest Monthly  Average of Min Temp       -0.147821
# Actual Yield (kg/ha)                            0.962198
# Trend (kg/ha)                                   1.000000
# Detrended Additive (kg/ha)                      0.239301
# Detrended Multiplicative (kg/ha)                0.225824
#
#                                            Detrended Additive (kg/ha)  \
# Yala Total Rainfall                                          0.016952
# Yala Temp Average                                            0.031014
# Yala Average Of Max Temp                                     0.055620
# Yala Highest Monthly  Average of Max Temp                    0.219162
# Yala Average Of Min Temp                                    -0.025914
# Yala Lowest Monthly  Average of Min Temp                    -0.011565
# Actual Yield (kg/ha)                                         0.494692
# Trend (kg/ha)                                                0.239301
# Detrended Additive (kg/ha)                                   1.000000
# Detrended Multiplicative (kg/ha)                             0.995210
#
#                                            Detrended Multiplicative (kg/ha)
# Yala Total Rainfall                                               -0.022363
# Yala Temp Average                                                  0.054197
# Yala Average Of Max Temp                                           0.078841
# Yala Highest Monthly  Average of Max Temp                          0.240338
# Yala Average Of Min Temp                                          -0.001466
# Yala Lowest Monthly  Average of Min Temp                          -0.015634
# Actual Yield (kg/ha)                                               0.481285
# Trend (kg/ha)                                                      0.225824
# Detrended Additive (kg/ha)                                         0.995210
# Detrended Multiplicative (kg/ha)                                   1.000000

# %%
import pandas as pd
from scipy.stats import pearsonr

# Calculate Pearson's correlation
for var in weather_columns:
    # Replace 'AverageYieldKgPERha' with the correct column name from your dataset
    # Assuming the correct column name is 'Actual Yield (kg/ha)' based on your previous code

    # Drop rows with NaN or inf in the relevant columns before calculating correlation
    valid_data = data[[var, 'Actual Yield (kg/ha)']].dropna().replace([np.inf, -np.inf], np.nan).dropna()

    correlation_coefficient, p_value = pearsonr(valid_data['Actual Yield (kg/ha)'], valid_data[var])
    print(f"Variable: {var}")
    print(f"  Pearson Correlation Coefficient (r): {correlation_coefficient:.2f}")
    print(f"  P-value: {p_value:.4f}")
    alpha = 0.05
    if p_value < alpha:
        print(f"  The correlation is statistically significant (p < {alpha}).")
        if correlation_coefficient > 0:
            print("  Positive linear relationship.")
        else:
            print("  Negative linear relationship.")
    else:
        print(f"  The correlation is not statistically significant (p >= {alpha}).")
    print()
# Out:
# Variable: Yala Total Rainfall
#   Pearson Correlation Coefficient (r): 0.44
#   P-value: 0.0124
#   The correlation is statistically significant (p < 0.05).
#   Positive linear relationship.
#
# Variable: Yala Temp Average
#   Pearson Correlation Coefficient (r): -0.05
#   P-value: 0.7784
#   The correlation is not statistically significant (p >= 0.05).
#
# Variable: Yala Average Of Max Temp
#   Pearson Correlation Coefficient (r): -0.12
#   P-value: 0.5264
#   The correlation is not statistically significant (p >= 0.05).
#
# Variable: Yala Highest Monthly  Average of Max Temp
#   Pearson Correlation Coefficient (r): -0.07
#   P-value: 0.6946
#   The correlation is not statistically significant (p >= 0.05).
#
# Variable: Yala Average Of Min Temp
#   Pearson Correlation Coefficient (r): 0.07
#   P-value: 0.7109
#   The correlation is not statistically significant (p >= 0.05).
#
# Variable: Yala Lowest Monthly  Average of Min Temp
#   Pearson Correlation Coefficient (r): -0.14
#   P-value: 0.4672
#   The correlation is not statistically significant (p >= 0.05).

# %%
import pandas as pd
from scipy.stats import pearsonr

# Calculate Pearson's correlation
for var in weather_columns:
    # Drop rows with NaN or inf in the relevant columns before calculating correlation
    # Include 'Trend (kg/ha)' in the columns used to create valid_data
    valid_data = data[[var, 'Actual Yield (kg/ha)', 'Trend (kg/ha)']].dropna().replace([np.inf, -np.inf], np.nan).dropna()

    correlation_coefficient, p_value = pearsonr(valid_data['Trend (kg/ha)'], valid_data[var])
    print(f"Variable: {var}")
    print(f"  Pearson Correlation Coefficient (r): {correlation_coefficient:.2f}")
    print(f"  P-value: {p_value:.4f}")
    alpha = 0.05
    if p_value < alpha:
        print(f"  The correlation is statistically significant (p < {alpha}).")
        if correlation_coefficient > 0:
            print("  Positive linear relationship.")
        else:
            print("  Negative linear relationship.")
    else:
        print(f"  The correlation is not statistically significant (p >= {alpha}).")
    print()
# Out:
# Variable: Yala Total Rainfall
#   Pearson Correlation Coefficient (r): 0.49
#   P-value: 0.0051
#   The correlation is statistically significant (p < 0.05).
#   Positive linear relationship.
#
# Variable: Yala Temp Average
#   Pearson Correlation Coefficient (r): -0.07
#   P-value: 0.7140
#   The correlation is not statistically significant (p >= 0.05).
#
# Variable: Yala Average Of Max Temp
#   Pearson Correlation Coefficient (r): -0.15
#   P-value: 0.4220
#   The correlation is not statistically significant (p >= 0.05).
#
# Variable: Yala Highest Monthly  Average of Max Temp
#   Pearson Correlation Coefficient (r): -0.15
#   P-value: 0.4183
#   The correlation is not statistically significant (p >= 0.05).
#
# Variable: Yala Average Of Min Temp
#   Pearson Correlation Coefficient (r): 0.09
#   P-value: 0.6471
#   The correlation is not statistically significant (p >= 0.05).
#
# Variable: Yala Lowest Monthly  Average of Min Temp
#   Pearson Correlation Coefficient (r): -0.15
#   P-value: 0.4274
#   The correlation is not statistically significant (p >= 0.05).
